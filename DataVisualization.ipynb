# %% [markdown]
# <a href="https://colab.research.google.com/github/ShamineDsouza/Python-Experiment/blob/main/DataVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sample_data/california_housing_test.csv')
df.head(3)
# df.plot()
df.plot(kind='scatter', x='latitude', y='total_rooms')

df.plot(kind='hist')
## df.plot(kind='area')
df.plot.bar()
plt.savefig('scatter.png')

# %%
df = pd.read_csv('sample_data/california_housing_test.csv')
df.head(3)

df.plot.pie(y='total_rooms',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='total_rooms'>
